# %% [markdown]
# <a href="https://colab.research.google.com/github/muralijsq/ASPNetCoreRazorPages/blob/master/Edu_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lab 01 - Explore Tokenization with titoken

# %%
# !pip -q install Ipython tiktoken transformers sentencepiece pandas matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 91.0 MB/s eta 0:00:00

# %%
from huggingface_hub import login
login()

# %%
import tiktoken
from transformers import AutoTokenizer
from IPython.display import display, HTML
import random
import pandas as pd
import matplotlib.pyplot as plt

# %%
gpt_tokennizer = tiktoken.encoding_for_model("gpt-4o")
mistral_tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
print("I want to do GPT-4o vocabulary size", gpt_tokennizer.n_vocab)
print("I want to do Mistral vocabulary size", mistral_tokenizer.vocab)
print("I want to do Mistral vocabulary size", mistral_tokenizer.vocab_size)
# Out:
# I want to do GPT-4o vocabulary size 200019
# I want to do Mistral vocabulary size {'mem': 3271, '▁punt': 16875, '▁nevertheless': 25457, 'Rend': 21544, 'abl': 13747, '▁wait': 2444, '▁hel': 1172, '▁recipe': 13405, 'LEN': 8880, '▁Sav': 11210, 'дж': 19450, 'ח': 29358, 'apol': 14095, 'ching': 11097, '▁Tol': 15893, 'VIS': 20178, '▁ov': 18611, 'ious': 925, 'definition': 15196, 'attan': 18244, '▁regarding': 8217, '▁pione': 21235, '▁contract': 5001, '▁Sql': 20950, '▁urban': 12270, '▁conform': 16565, 'дова': 11346, '占': 30825, 'inois': 13240, '▁fix': 6293, '못': 31408, 'ocy': 26720, 'Diagnostics': 18174, 'propri': 23232, 'Supp': 15653, '▁viable': 27826, '▁suddenly': 6914, 'ญ': 31064, 'Allowed': 23278, '▁mum': 27870, '▁gewann': 26778, 'ال': 14312, '\'",': 27354, 'Proxy': 11950, '▁tanks': 20274, '▁resulted': 16960, 'awn': 11646, 'rypto': 10690, 'REF': 14329, '论': 30144, '▁aircraft': 11475, 'ntil': 12662, '您': 29689, '▁systems': 4918, 'ider': 1184, '▁Saudi': 24613, '▁sau': 10241, 'ර': 31532, 'elve': 11047, 'Ḥ': 30231, 'Manifest': 27980, '▁recover': 9443, '▁developed': 6202, 'リ': 29306, '▁tut': 8311, '▁todas': 24209, 'bres': 13243, 'scriptstyle': 26715, 'deg': 13780, 'olu': 17760, '▁governed': 22175, '▁assistance': 11611, '▁bal': 4549, '▁Ś': 18730, 'But': 2438, '铺': 31471, '▁j': 461, '여': 29827, 'logs': 25850, 'olate': 19807, '▁Turkey': 17915, '▁refriger': 23641, '▁even': 1019, 'шей': 22728, '▁full': 2173, '▁bru': 16575, 'стратив': 21636, 'Shared': 15686, 'art': 444, '▁wondered': 10662, 'ular': 1098, '▁complaining': 26509, '▁janu': 19173, '▁never': 1484, '▁insert': 8561, 'tesy': 18414, '▁arrog': 28327, 'ystem': 906, '▁afford': 8205, '▁Average': 27701, '▁primera': 14422, 'nate': 25134, '刀': 31516, '\u200b': 28935, '▁eu': 19932, 'hooks': 25142, '▁peculiar': 25876,